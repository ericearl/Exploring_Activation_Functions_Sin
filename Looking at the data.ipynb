# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
test_df = pd.read_csv('./tests/test_1/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %% [markdown]
# It's pretty clear Sin was the worst for this architecture.

# %%
test_df = pd.read_csv('./tests/test_2/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_3/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_4/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_5/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_6/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_7/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_8/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()

# %%
test_df = pd.read_csv('./tests/test_9/training_history.csv', index_col=0)
history = test_df.loc['val_loss'].apply(lambda x: np.asarray(x[1:-1].split(','), dtype='float'))

plt.plot(history['relu'])
plt.plot(history['sigmoid'])
plt.plot(history['tanh'])
plt.plot(history['sin'])
plt.legend(['relu', 'sigmoid', 'tanh', 'sin'])
plt.show()
